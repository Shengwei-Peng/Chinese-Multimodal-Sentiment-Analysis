# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://github.com/SaChiShark/MMSA.git
# !pip install ./MMSA
# Out:
# Cloning into 'MMSA'...
# remote: Enumerating objects: 1380, done.
# remote: Counting objects: 100% (328/328), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 1380 (delta 165), reused 257 (delta 148), pack-reused 1052
# Receiving objects: 100% (1380/1380), 9.29 MiB | 20.11 MiB/s, done.
# Resolving deltas: 100% (810/810), done.
# Processing ./MMSA
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for MMSA: filename=MMSA-2.2.1-py3-none-any.whl size=118876 sha256=cf901ef3816020302a1cbf55f615615fde2978792f182fd84aec5785bd215227
#   Stored in directory: /tmp/pip-ephem-wheel-cache-53ln1nxq/wheels/f2/a7/a9/dc2fa655bdcb3c1de6efcae3674c538b93a9fc179e1964be21
# ...

# %%
# !pip install gdown
# !gdown --id 1R0WUJui1utRBi-gtJK-2MxGiZrwKcDmv
# !gdown --id 1l_Nb9h3BRa3S-N76YcSQ3ixakr0gn6Qr
# Out:
# ...
# /opt/conda/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1R0WUJui1utRBi-gtJK-2MxGiZrwKcDmv
# To: /kaggle/working/label.csv
# 100%|█████████████████████████████████████████| 222k/222k [00:00<00:00, 731kB/s]
# /opt/conda/lib/python3.10/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1l_Nb9h3BRa3S-N76YcSQ3ixakr0gn6Qr
# From (redirected): https://drive.google.com/uc?id=1l_Nb9h3BRa3S-N76YcSQ3ixakr0gn6Qr&confirm=t&uuid=768625f1-e01d-4959-a8eb-e71bd8516b37
# To: /kaggle/working/unaligned_39.pkl
# ...

# %%
from MMSA import MMSA_run, get_config_regression
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
model = 'self_mm'
config = get_config_regression(model, 'sims')
config['featurePath'] = '/kaggle/working/unaligned_39.pkl'
MMSA_run(model, 'sims', config = config,model_save_dir = './',res_save_dir = './', log_dir = './',seeds=[1111])
# Out:
# MMSA - ======================================== Program Start ========================================
# MMSA - Running with args:
# ...

# %%
model = 'mlmf'
config = get_config_regression(model, 'sims')
config['featurePath'] = '/kaggle/working/unaligned_39.pkl'
MMSA_run(model, 'sims', config = config,model_save_dir = './',res_save_dir = './', log_dir = './',seeds=[1111])
# Out:
# MMSA - ======================================== Program Start ========================================
# MMSA - ======================================== Program Start ========================================
# MMSA - Running with args:
# MMSA - Running with args:
# ...

# %%
model = 'mtfn'
config = get_config_regression(model, 'sims')
config['featurePath'] = '/kaggle/working/unaligned_39.pkl'
MMSA_run(model, 'sims', config = config,model_save_dir = './',res_save_dir = './', log_dir = './',seeds=[1111])
# Out:
# MMSA - ======================================== Program Start ========================================
# MMSA - ======================================== Program Start ========================================
# MMSA - ======================================== Program Start ========================================
# MMSA - Running with args:
# MMSA - Running with args:
# MMSA - Running with args:
# ...

# %%
model = 'mmim'
config = get_config_regression(model, 'sims')
config['featurePath'] = '/kaggle/working/unaligned_39.pkl'
MMSA_run(model, 'sims', config = config,model_save_dir = './',res_save_dir = './', log_dir = './',seeds=[1111])
# Out:
# MMSA - ======================================== Program Start ========================================
# MMSA - ======================================== Program Start ========================================
# MMSA - ======================================== Program Start ========================================
# MMSA - ======================================== Program Start ========================================
# MMSA - Running with args:
# MMSA - Running with args:
# MMSA - Running with args:
# MMSA - Running with args:
# ...

# %%
import pickle
with open('/kaggle/working/unaligned_39.pkl', "rb") as f:
    eature = pickle.load(f)

# %%
from MMSA import MMSA_test

# %%
i = 1

# %%
featture = {}
featture['text_bert'] = eature['train']['text_bert'][i]
featture['text'] = eature['train']['text'][i]
featture['audio'] = eature['train']['audio'][i]
featture['vision'] = eature['train']['vision'][i]
eature['train']['raw_text'][i]
# Out:
# '听得见吗，只要我活着，我就会记住你'

# %%
print(MMSA_test(config = get_config_regression('self_mm', 'sims'), weights_path = '/kaggle/working/self_mm-sims.pth', feature = featture))
print(MMSA_test(config = get_config_regression('mlmf', 'sims'), weights_path = '/kaggle/working/mlmf-sims.pth', feature = featture))
print(MMSA_test(config = get_config_regression('mtfn', 'sims'), weights_path = '/kaggle/working/mtfn-sims.pth', feature = featture))
print(MMSA_test(config = get_config_regression('mmim', 'sims'), weights_path = '/kaggle/working/mtfn-sims.pth', feature = featture))
# Out:
# -1.0735937
# 0.022825284
# -1.0097198
# 0.0108393915
